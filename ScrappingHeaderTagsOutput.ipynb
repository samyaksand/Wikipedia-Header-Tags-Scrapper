# %%
import requests
from bs4 import BeautifulSoup

url = requests.get('https://en.wikipedia.org/wiki/Software_engineering')
bs = BeautifulSoup(url.text, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('Displaying all Header Tags :', *titles, sep='\n\n')
# Out:
# Displaying all Header Tags :
#
# <h1 class="firstHeading" id="firstHeading">Software engineering</h1>
#
# <h2 id="mw-toc-heading">Contents</h2>
#
# <h2><span class="mw-headline" id="History">History</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Software_engineering&amp;action=edit&amp;section=1" title="Edit section: History">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#
# <h2><span class="mw-headline" id="Definitions_and_terminology_controversies">Definitions and terminology controversies</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Software_engineering&amp;action=edit&amp;section=2" title="Edit section: Definitions and terminology controversies">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#
# ...
